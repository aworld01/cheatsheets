# %%
a = 1 == True
a
# Out:
# True

# %%
b = 2 == True
b
# Out:
# False

# %%
c = 0 == False
c
# Out:
# True

# %%
d = 1 == False
d
# Out:
# False

# %%
"""example2"""
a = 7 + True
a
# Out:
# 8

# %%
b = 7 + False
b
# Out:
# 7

# %%
c = 7 * False
c
# Out:
# 0
