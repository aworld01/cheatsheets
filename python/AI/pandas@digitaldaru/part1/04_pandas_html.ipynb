# %%
import pandas as pd

file_html = r"https://en.wikipedia.org/wiki/list_of_highest-grossing_Indian_films"

# %%
df = pd.read_html(file_html)
print(df)
# Out:
# [    Rank  Peak                            Film  Year               Director  \
# 0      1     1                          Dangal  2016          Nitesh Tiwari
# 1      2     1     Baahubali 2: The Conclusion  2017        S. S. Rajamouli
# 2      3     3                           RRR *  2022        S. S. Rajamouli
# 3      4     3                K.G.F: Chapter 2  2022         Prashanth Neel
# 4      5     5                         Pathaan  2023        Siddharth Anand
# 5      6     3               Bajrangi Bhaijaan  2015             Kabir Khan
# 6      7     3                Secret Superstar  2017         Advait Chandan
# 7      8     1                              PK  2014        Rajkumar Hirani
# 8      9     3                          Sultan  2016        Ali Abbas Zafar
# 9     10     7                             2.0  2018             S. Shankar
# 10    11     2        Baahubali: The Beginning  2015        S. S. Rajamouli
# ...
