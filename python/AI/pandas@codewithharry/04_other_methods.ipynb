# %%
"""44:00 / 1:05:23"""
import pandas as pd

df = pd.read_csv("friends.csv")
df
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 1    Rohan     Kolkata     34
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 4    Aamit     Kolkata     15
# 5    Ahmed       Delhi     14
# 6  Raheman      Mumbai     34

# %%
id(df) #to check file location
# Out:
# 2437043491024

# %%
new_df = df #this is only view of df
id(new_df)
# Out:
# 2437043491024

# %%
new_df2 = df.copy() #this is a new copy of df
id(new_df2)
# Out:
# 2437027525456

# %%
df
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 1    Rohan     Kolkata     34
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 4    Aamit     Kolkata     15
# 5    Ahmed       Delhi     14
# 6  Raheman      Mumbai     34

# %%
new_df.loc[0, "name"] = "Abdul" #to update data
df
# Out:
#       name        city  marks
# 0    Abdul      Rampur     92
# 1    Rohan     Kolkata     34
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 4    Aamit     Kolkata     15
# 5    Ahmed       Delhi     14
# 6  Raheman      Mumbai     34

# %%
df.columns = ["A", "B", "C"] #to change columns name
df
# Out:
#          A           B   C
# 0    Abdul      Rampur  92
# 1    Rohan     Kolkata  34
# 2   Skillf    Bareilly  24
# 3    Shubh  Antarctica  17
# 4    Aamit     Kolkata  15
# 5    Ahmed       Delhi  14
# 6  Raheman      Mumbai  34

# %%
new_df = df.drop(0, axis=0)
new_df
# Out:
#          A           B   C
# 1    Rohan     Kolkata  34
# 2   Skillf    Bareilly  24
# 3    Shubh  Antarctica  17
# 4    Aamit     Kolkata  15
# 5    Ahmed       Delhi  14
# 6  Raheman      Mumbai  34

# %%
df.loc[[1,4], ["B", "C"]] #it's only return the value not change
# Out:
#          B   C
# 1  Kolkata  34
# 4  Kolkata  15

# %%
df.loc[:, ["B", "C"]] #to retreive all columns
# Out:
#             B   C
# 0      Rampur  92
# 1     Kolkata  34
# 2    Bareilly  24
# 3  Antarctica  17
# 4     Kolkata  15
# 5       Delhi  14
# 6      Mumbai  34

# %%
df.loc[[1,2],] #to retrieve all rows
# Out:
#         A         B   C
# 1   Rohan   Kolkata  34
# 2  Skillf  Bareilly  24

# %%
df.loc[(df["C"]<20)] #to reterive values that is < 20
# Out:
#        A           B   C
# 3  Shubh  Antarctica  17
# 4  Aamit     Kolkata  15
# 5  Ahmed       Delhi  14

# %%
# df.loc[(df["A"] < 20) & (df["C"] > 10)]

# %%
"""iloc"""
df.iloc[0, 2] #to select by index
# Out:
# 92

# %%
df.iloc[[0,2], [1,2]]
# Out:
#           B   C
# 0    Rampur  92
# 2  Bareilly  24

# %%
df
# Out:
#          A           B   C
# 0    Abdul      Rampur  92
# 1    Rohan     Kolkata  34
# 2   Skillf    Bareilly  24
# 3    Shubh  Antarctica  17
# 4    Aamit     Kolkata  15
# 5    Ahmed       Delhi  14
# 6  Raheman      Mumbai  34

# %%
df.drop([1]) #to delete row
# Out:
#          A           B   C
# 0    Abdul      Rampur  92
# 2   Skillf    Bareilly  24
# 3    Shubh  Antarctica  17
# 4    Aamit     Kolkata  15
# 5    Ahmed       Delhi  14
# 6  Raheman      Mumbai  34

# %%
df.drop([1, 3]) #to delete multiple columns
# Out:
#          A         B   C
# 0    Abdul    Rampur  92
# 2   Skillf  Bareilly  24
# 4    Aamit   Kolkata  15
# 5    Ahmed     Delhi  14
# 6  Raheman    Mumbai  34

# %%
df.drop(["A"], axis=1) #to delete column
# Out:
#             B   C
# 0      Rampur  92
# 1     Kolkata  34
# 2    Bareilly  24
# 3  Antarctica  17
# 4     Kolkata  15
# 5       Delhi  14
# 6      Mumbai  34

# %%
df.drop(["A", "C"], axis=1) #to delete multiple columns
# Out:
#             B
# 0      Rampur
# 1     Kolkata
# 2    Bareilly
# 3  Antarctica
# 4     Kolkata
# 5       Delhi
# 6      Mumbai

# %%
df
# Out:
#          A           B   C
# 0    Abdul      Rampur  92
# 1    Rohan     Kolkata  34
# 2   Skillf    Bareilly  24
# 3    Shubh  Antarctica  17
# 4    Aamit     Kolkata  15
# 5    Ahmed       Delhi  14
# 6  Raheman      Mumbai  34

# %%
df.drop(["A", "C"], axis=1, inplace=True) #to change the original data

# %%
df
# Out:
#             B
# 0      Rampur
# 1     Kolkata
# 2    Bareilly
# 3  Antarctica
# 4     Kolkata
# 5       Delhi
# 6      Mumbai
