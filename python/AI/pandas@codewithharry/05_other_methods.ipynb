# %%
import pandas as pd

df = pd.read_csv("friends.csv")
df
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 1    Rohan     Kolkata     34
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 4    Harry      Ranchi     93
# 5    Aamit     Kolkata     15
# 6    Ahmed       Delhi     14
# 7  Raheman      Mumbai     34

# %%
df.drop([1,5], axis=0)
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 4    Harry      Ranchi     93
# 6    Ahmed       Delhi     14
# 7  Raheman      Mumbai     34

# %%
df.drop(["name", "marks"], axis=1)
# Out:
#          city
# 0      Rampur
# 1     Kolkata
# 2    Bareilly
# 3  Antarctica
# 4      Ranchi
# 5     Kolkata
# 6       Delhi
# 7      Mumbai

# %%
new_df = df.drop([1,5])
new_df
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 4    Harry      Ranchi     93
# 6    Ahmed       Delhi     14
# 7  Raheman      Mumbai     34

# %%
# new_df.reset_index() #to reset index (but adds one more column)
new_df.reset_index(drop=True) #to reset index
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 1   Skillf    Bareilly     24
# 2    Shubh  Antarctica     17
# 3    Harry      Ranchi     93
# 4    Ahmed       Delhi     14
# 5  Raheman      Mumbai     34

# %%
"""drop_duplicates"""
df
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 1    Rohan     Kolkata     34
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 4    Harry      Ranchi     93
# 5    Aamit     Kolkata     15
# 6    Ahmed       Delhi     14
# 7  Raheman      Mumbai     34

# %%
df.drop_duplicates(subset=["name"]) #to remove duplicate values
# Out:
#       name        city  marks
# 0    Harry      Rampur     92
# 1    Rohan     Kolkata     34
# 2   Skillf    Bareilly     24
# 3    Shubh  Antarctica     17
# 5    Aamit     Kolkata     15
# 6    Ahmed       Delhi     14
# 7  Raheman      Mumbai     34

# %%
df = pd.read_csv("friends.csv")
# df["name"].value_counts() #remove NaN
df["name"].value_counts(dropna=True)
# Out:
# name
# Harry      2
# Rohan      1
# Skillf     1
# Shubh      1
# Aamit      1
# Ahmed      1
# Raheman    1
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#     name   city  marks
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False
# 6  False  False  False
# 7  False  False  False

# %%
df.notnull()
# Out:
#    name  city  marks
# 0  True  True   True
# 1  True  True   True
# 2  True  True   True
# 3  True  True   True
# 4  True  True   True
# 5  True  True   True
# 6  True  True   True
# 7  True  True   True

# %%
# df.describe()
# df.mean()
# df.corr()
# df.count()
# df.max()
# df.min()
# df.median()
# df.std()
