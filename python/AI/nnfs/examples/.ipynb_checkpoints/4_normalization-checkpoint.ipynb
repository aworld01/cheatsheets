# %% [markdown]
# <h1>Normalization</h1>

# %%
x = [10,20,40,30]

# %%
norm_base = sum(x)
norm_value = []

# %%
for value in x:
    norm_value.append(value/norm_base)

# %%
print(x)
print(norm_base)
print(norm_value)
# Out:
# [10, 20, 40, 30]
# 100
# [0.1, 0.2, 0.4, 0.3]

# %% [markdown]
# <h2>Example with function</h2>

# %%
def normalization(arg):
    norm_base = sum(arg)
    norm_value = []
    for value in arg:
        norm_value.append(value/norm_base)
    return norm_value

# %%
normalization(x)
# Out:
# [0.1, 0.2, 0.4, 0.3]
