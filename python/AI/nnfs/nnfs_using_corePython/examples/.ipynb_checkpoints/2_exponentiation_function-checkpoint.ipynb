# %% [markdown]
# <h2>Exponentiation Function</h2>

# %%
import math
import numpy as np

# %%
x1 = 2
x2 = [4.8,1.21,2.385]
x3 = [[4.8,1.21,2.385],
      [8.9,1.81,0.2],
      [1.41,1.051,0.026]]

# %% [markdown]
# <h2>it supports only a 'scaler' value</h2>

# %%
math.exp(x1) #returns a 'scaler' value
# Out:
# 7.38905609893065

# %% [markdown]
# <h2>it supports 'scaler' and 'matrix' both</h2>

# %%
np.exp(x1) #it returns a 'scaler' value
# Out:
# 7.38905609893065

# %%
np.exp(x2) #it returns a 'matrix' array
# Out:
# array([121.51041752,   3.35348465,  10.85906266])

# %% [markdown]
# <h2>This will support 'scaler' and 'matrix' both</h2>

# %%
def exp2(arg):
    if isinstance(arg, list):
        l = []
        for i in arg:
            l.append(math.exp(i))
        return l
    else:
        return math.exp(arg)

# %%
exp2(x1) #it returns a 'scaler' value
# Out:
# 7.38905609893065

# %%
exp2(x2) #it will return a 'matrix'
# Out:
# [121.51041751873485, 3.3534846525490236, 10.859062664920515]

# %% [markdown]
# <h2>Exponentiation with 2d matrix</h2>

# %%
def exp3(arg):
    outputs = []
    if isinstance(arg,list):
        for lst in range(len(arg)):
            l = arg[lst]
            ex = []
            for i in range(len(l)):
                ex.append(math.exp(l[i]))
            outputs.append(ex)
    return outputs

# %%
exp3(x3)
# Out:
# [[121.51041751873485, 3.3534846525490236, 10.859062664920515],
#  [7331.973539155995, 6.11044743223061, 1.2214027581601699],
#  [4.095955404071176, 2.86051019848318, 1.026340948473442]]

# %%
np.exp(x3)
# Out:
# array([[1.21510418e+02, 3.35348465e+00, 1.08590627e+01],
#        [7.33197354e+03, 6.11044743e+00, 1.22140276e+00],
#        [4.09595540e+00, 2.86051020e+00, 1.02634095e+00]])

# %% [markdown]
# <h3>Example of isinstance</h3>

# %%
a = 2
b = [2,3,5,6]

# %%
if isinstance(b,list):
    print('This is a list')
else:
    print('This is a number')
# Out:
# This is a list
